# %%
import allen2tract.util as a2tu
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache
import os
import pandas as pd
from pathlib import Path

# %%
res = 100
manifest = "/Users/mahdi/stage-2022-mahdi/cache/mouse_conn_manifest.json"

# %%
id = 288169135

# %%
mcc = MouseConnectivityCache(resolution=res, manifest_file=manifest)

# %%
mcc.get_projection_density(id, "{}_{}.nrrd".format(id, res))

# %%
structures = "/Users/mahdi/stage-2022-mahdi/cache/structures.json"

# %%
st = mcc.get_structure_tree()
structs = st.get_structures_by_set_id([184527634])
structs_ids = pd.DataFrame(structs).id.tolist()

# %%
mcc.get_structure_unionizes(
    experiment_ids=[id], 
    is_injection=False,
    structure_ids=structs_ids,
    )
# Out:
#       experiment_id  hemisphere_id  ...  sum_projection_pixels    volume
# 0         288169135              2  ...           3.112514e+04  0.080830
# 1         288169135              1  ...           1.560650e+04  0.231069
# 2         288169135              1  ...           1.700430e+05  0.423071
# 3         288169135              2  ...           1.587514e+03  0.010515
# 4         288169135              2  ...           1.398112e+07  2.426253
# ...             ...            ...  ...                    ...       ...
# 2491      288169135              3  ...           3.380350e+07  0.758505
# 2492      288169135              2  ...           7.030653e+07  0.714444
# 2493      288169135              2  ...           1.151876e+06  0.390116
# 2494      288169135              1  ...           8.273998e+03  0.020688
# 2495      288169135              3  ...           2.857017e+08  3.352753
#
# [2496 rows x 19 columns]
